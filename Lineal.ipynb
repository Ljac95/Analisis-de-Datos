# %%
#Cargar Las Librerias Necesarias

import pandas as pd # Manaejo y analisisi de estructura de datos
import numpy as np # Calculo numérico y el analisis de datps
import seaborn as sns # Creación Graficos estadisticos
import matplotlib.pyplot as plt # Creación de graficos en dos dimensiones

#Librerias para implementar modelos de ciencia de datos
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
Datveh = pd.read_csv(r'C:\Users\Administrator\Car details v3.csv')

# %%
Datveh.head(50)
# Out:
#                                            name  year  selling_price  \
# 0                        Maruti Swift Dzire VDI  2014         450000
# 1                  Skoda Rapid 1.5 TDI Ambition  2014         370000
# 2                      Honda City 2017-2020 EXi  2006         158000
# 3                     Hyundai i20 Sportz Diesel  2010         225000
# 4                        Maruti Swift VXI BSIII  2007         130000
# 5                 Hyundai Xcent 1.2 VTVT E Plus  2017         440000
# 6                  Maruti Wagon R LXI DUO BSIII  2007          96000
# 7                            Maruti 800 DX BSII  2001          45000
# 8                              Toyota Etios VXD  2011         350000
# 9          Ford Figo Diesel Celebration Edition  2013         200000
# 10              Renault Duster 110PS Diesel RxL  2014         500000
# 11                                Maruti Zen LX  2005          92000
# 12                       Maruti Swift Dzire VDi  2009         280000
# ...

# %%
Datveh.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
plt.figure(figsize=(6, 3))
sns.boxplot(x=Datveh ['year'])
plt.title('Identificación de Datos Faltantes y Atipico', fontsize=12)
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Faltantes y Atipico')

# %%
#Revisión de Registros Faltantes

print("Cantidad de Registros con la cantidad de sillas sin Información: ",Datveh ['seats'].isna().sum())
# Out:
# Cantidad de Registros con la cantidad de sillas sin Información:  221

# %%
Datveh['seats'] = Datveh['seats'].fillna(Datveh['seats'].mean())

# %%
print("Cantidad de Registros con la cantidad de sillas sin Información: ",Datveh ['seats'].isna().sum())
# Out:
# Cantidad de Registros con la cantidad de sillas sin Información:  0

# %%
#Identificación de Datos Atípicos

plt.figure(figsize=(6, 3))
sns.boxplot(x=Datveh['km_driven'])
plt.title ('Identificación de Datos Atípicos',fontsize=12 )
# Out:
# Text(0.5, 1.0, 'Identificación de Datos Atípicos')

# %%
#Contar Datos Atípicos
nivel_minimo=1
nivel_maximo=300000
Total_Atipicos=((Datveh['km_driven']<nivel_minimo)|(Datveh['km_driven']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 18

# %%
# Filtrar Datos Atípicos
Datveh=Datveh[(Datveh['km_driven']<nivel_maximo)&(Datveh['km_driven']>nivel_minimo)]

# %%
#Contar Datos Atípicos
nivel_minimo=1
nivel_maximo=300000
Total_Atipicos=((Datveh['km_driven']<nivel_minimo)|(Datveh['km_driven']>nivel_maximo)).sum()
print("El total de datos atípicos es {}".format(Total_Atipicos))
# Out:
# El total de datos atípicos es 0

# %%
# Revisión del tipo de datos y Datos Faltantes

Datveh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8100 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8100 non-null   object
#  1   year           8100 non-null   int64
#  2   selling_price  8100 non-null   int64
#  3   km_driven      8100 non-null   int64
#  4   fuel           8100 non-null   object
#  5   seller_type    8100 non-null   object
#  6   transmission   8100 non-null   object
#  7   owner          8100 non-null   object
#  8   mileage        7879 non-null   object
#  9   engine         7879 non-null   object
#  10  max_power      7885 non-null   object
#  11  torque         7878 non-null   object
#  12  seats          8100 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 885.9+ KB

# %%
# Total carros por precio de venta

Datveh['selling_price'].value_counts()
# Out:
# selling_price
# 300000     226
# 600000     213
# 350000     207
# 550000     201
# 450000     193
#           ...
# 174000       1
# 308000       1
# 3900000      1
# 2850000      1
# 746000       1
# Name: count, Length: 675, dtype: int64

# %%
Datveh[['selling_price']].head(13)
# Out:
#     selling_price
# 0          450000
# 1          370000
# 2          158000
# 3          225000
# 4          130000
# 5          440000
# 6           96000
# 7           45000
# 8          350000
# 9          200000
# 10         500000
# 11          92000
# 12         280000

# %%
# Se crean las variables x y y para almacenar la información del entrenamiento

from sklearn.model_selection import train_test_split

# Se crean las variables X e Y para almacenar la información del entrenamiento
X = Datveh.drop('seats', axis=1)
Y = Datveh['seats']

# División aleatoria de los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=5)

# %%
print (X_train)
# Out:
#                                                  name  year  selling_price  \
# 7046                               Hyundai Santro Era  2019         420000
# 5138                           Chevrolet Spark 1.0 LT  2011         150000
# 4646                         Tata Indica Vista TDI LX  2011         350000
# 7295  Volkswagen Passat Highline DSG S (Spl. Edition)  2012         799000
# 3244                            Maruti Ciaz 1.3 Alpha  2017         800000
# ...                                               ...   ...            ...
# 3058                        Hyundai Creta 1.6 CRDi SX  2015         850000
# 1729                Toyota Etios Liva 1.2 V Dual Tone  2017         585000
# 4095                              Honda WR-V i-VTEC S  2017         700000
# 2262             Ford Figo Diesel Celebration Edition  2013         229999
# 2925                      Ford Figo Diesel EXI Option  2010         185000
#
# ...

# %%
print (Y_train)
# Out:
# 7046    5.0
# 5138    5.0
# 4646    5.0
# 7295    5.0
# 3244    5.0
#        ...
# 3058    5.0
# 1729    5.0
# 4095    5.0
# 2262    5.0
# 2925    5.0
# Name: seats, Length: 6075, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# Se crean las variables X e Y para almacenar la información del entrenamiento
Datveh=Datveh [['selling_price','km_driven','year']]
X = Datveh.drop('selling_price', axis=1)
Y = Datveh['selling_price']

# División aleatoria de los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=5)

# %%
modelo_regression=LinearRegression()
modelo_regression.fit(X_train, Y_train)
Prediccion= modelo_regression.predict(X_test)

# %%
print (Y_test)
# Out:
# 1109     450000
# 784      220000
# 8104     160000
# 517      540000
# 5368     220000
#          ...
# 3007     875000
# 1886     118000
# 3615     310000
# 5981     560000
# 7368    1450000
# Name: selling_price, Length: 2025, dtype: int64

# %%
print (Prediccion)
# Out:
# [ 8.79418203e+05 -1.12598794e+02  7.39565504e+04 ...  9.89741206e+05
#   3.09641431e+05  1.09074631e+06]

# %%
print(classification_report)
# Out:
# <function classification_report at 0x0000025293520CC0>

# %%
Prediccion = modelo_regresion.predict(X_test)

# %%
for i in range(len(Prediccion)):
    print("Predicción:", Prediccion[i], "Valor real:", Y_test.iloc[i])
# Out:
# Predicción: 879418.2029298246 Valor real: 450000
# Predicción: -112.59879356622696 Valor real: 220000
# Predicción: 73956.5503590107 Valor real: 160000
# Predicción: 835135.2529741228 Valor real: 540000
# Predicción: 344652.4993914664 Valor real: 220000
# Predicción: 910956.8466390073 Valor real: 400000
# Predicción: 857355.9977198839 Valor real: 610000
# Predicción: 927794.1825110912 Valor real: 362000
# Predicción: 285397.18006941676 Valor real: 320000
# Predicción: 1004555.0361005366 Valor real: 640000
# Predicción: 536564.0887929201 Valor real: 750000
# Predicción: 462494.9396403134 Valor real: 310000
# Predicción: 787730.9975164533 Valor real: 565000
# Predicción: 867501.9897707999 Valor real: 750000
# Predicción: 668678.2358137965 Valor real: 484999
# Predicción: 1011961.9510157704 Valor real: 790000
# Predicción: 273275.0546757281 Valor real: 130000
# Predicción: 157456.12046843767 Valor real: 120000
# Predicción: 459803.23520350456 Valor real: 275000
# ...

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Calcular el error cuadrático medio
mse = mean_squared_error(Y_test, Prediccion)
print("Error cuadrático medio:", mse)

# Calcular el coeficiente de determinación
r2 = r2_score(Y_test, Prediccion)
print("Coeficiente de determinación:", r2)
# Out:
# Error cuadrático medio: 592765101972.7722
# Coeficiente de determinación: 0.19238053062184757

# %%
#Grafica Lineal

fig = plt.figure()
plt.scatter(Y_test, Y_train)
plt.xlabel('Y_test')
plt.ylabel('Y_train')
plt.title('Y_test vs Y_train')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[156], line 4
#       1 #Grafica Lineal
#       3 fig = plt.figure()
# ----> 4 plt.scatter(Y_test, Y_train)
#       5 plt.xlabel('Y_test')
#       6 plt.ylabel('Y_train')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\pyplot.py:3687, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3668 @_copy_docstring_and_deprecators(Axes.scatter)
#    3669 def scatter(
#    3670     x: float | ArrayLike,
#    (...)
#    3685     **kwargs,
#    3686 ) -> PathCollection:
# -> 3687     __ret = gca().scatter(
#    3688         x,
#    3689         y,
#    3690         s=s,
#    3691         c=c,
#    3692         marker=marker,
#    3693         cmap=cmap,
#    3694         norm=norm,
#    3695         vmin=vmin,
#    3696         vmax=vmax,
# ...
